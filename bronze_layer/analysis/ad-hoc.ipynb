-- %% [markdown]
-- ## Movies

-- %%
%python
spark.sql("SELECT * FROM netflix.`01_bronze`.br_movies").printSchema()

-- %%
SELECT * 
FROM netflix.`01_bronze`.br_movies 
LIMIT 10

-- %%
SELECT DISTINCT `_rescued_data`
FROM netflix.`01_bronze`.br_movies

-- %%
select * from netflix.`02_silver`.stg_movies

-- %% [markdown]
-- ## Belief Data

-- %%
%python
spark.sql("SELECT * FROM netflix.`01_bronze`.br_belief_data").printSchema()

-- %%
%sql 
SELECT * FROM netflix.`01_bronze`.br_belief_data;

-- %%
%python
print(spark.sql("SELECT count(*) FROM netflix.`01_bronze`.br_user_rating_history").display())
print(spark.sql("SELECT count(*) FROM netflix.`01_bronze`.br_ratings_for_additional_users").display())
print(spark.sql("SELECT count(*) FROM netflix.`02_silver`.stg_ratings").display())

-- %%
select distinct user_elicit_rating from netflix.`02_silver`.stg_beliefs
